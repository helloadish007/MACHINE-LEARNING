# %% [markdown]
# # PYTHON PANDAS

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/home/adish/Desktop/PROJECT_DATASET/s4.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Register No  CS202_internas   CS202  IT202_internals IT202  IT204_internals  \
# 0  TRV16IT001              25       F               29     F               31
# 1  TRV16IT002              35  Absent               37     B               44
# 2  TRV16IT003              48       B               47     A               45
# 3  TRV16IT005              40       B               46     A               40
# 4  TRV16IT006              34       C               43     F               42
#
#   IT204 HS200_internals HS200 MA202_internals MA202  CS208_internals CS208  \
# 0    B+              25     C              29    B+               32     C
# 1    B+              23     C              32    B+               32     C
# 2    A+              44    B+              49     O               50    A+
# 3    B+              41     A              46     O               45     A
# 4     B              40    B+              45     O               37     B
#
# ...

# %%
df['Register No']
# Out:
# 0     TRV16IT001
# 1     TRV16IT002
# 2     TRV16IT003
# 3     TRV16IT005
# 4     TRV16IT006
# 5     TRV16IT007
# 6     TRV16IT008
# 7     TRV16IT009
# 8     TRV16IT010
# 9     TRV16IT011
# 10    TRV16IT012
# 11    TRV16IT013
# 12    TRV16IT015
# 13    TRV16IT016
# 14    TRV16IT017
# 15    TRV16IT018
# 16    TRV16IT019
# 17    TRV16IT020
# 18    TRV16IT021
# 19    TRV16IT022
# 20    TRV16IT023
# 21    TRV16IT024
# 22    TRV16IT025
# 23    TRV16IT026
# 24    TRV16IT028
# 25    TRV16IT030
# 26    TRV16IT031
# 27    TRV16IT032
# 28    TRV16IT033
# 29    TRV16IT034
# 30    TRV16IT035
# 31    TRV16IT036
# 32    TRV16IT037
# 33    TRV16IT038
# 34    TRV16IT039
# 35    TRV16IT040
# 36    TRV16IT041
# 37    TRV16IT042
# 38    TRV16IT043
# 39    TRV16IT044
# 40    TRV16IT045
# 41    TRV16IT046
# 42    TRV16IT048
# 43    TRV16IT049
# 44    TRV16IT050
# 45    TRV16IT051
# 46    TRV16IT052
# 47    TRV16IT053
# 48    TRV16IT054
# 49    TRV16IT055
# 50    TRV16IT056
# 51    TRV16IT057
# ...

# %%
type(df['Register No'])
# Out:
# pandas.core.series.Series

# %%
df['Register No'].head()
# Out:
# 0    TRV16IT001
# 1    TRV16IT002
# 2    TRV16IT003
# 3    TRV16IT005
# 4    TRV16IT006
# Name: Register No, dtype: object

# %%
df.shape
# Out:
# (57, 17)

# %%
df.columns
# Out:
# Index(['Register No', 'CS202_internas', 'CS202', 'IT202_internals', 'IT202',
#        'IT204_internals', 'IT204', 'HS200_internals', 'HS200',
#        'MA202_internals', 'MA202', 'CS208_internals', 'CS208',
#        'IT232_internals', 'IT232', 'IT234_internals', 'IT234'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 17 columns):
# Register No        57 non-null object
# CS202_internas     57 non-null int64
# CS202              57 non-null object
# IT202_internals    57 non-null int64
# IT202              57 non-null object
# IT204_internals    57 non-null int64
# IT204              57 non-null object
# HS200_internals    57 non-null object
# HS200              57 non-null object
# MA202_internals    57 non-null object
# MA202              57 non-null object
# CS208_internals    57 non-null int64
# CS208              57 non-null object
# IT232_internals    57 non-null int64
# IT232              57 non-null object
# IT234_internals    57 non-null int64
# IT234              57 non-null object
# dtypes: int64(6), object(11)
# memory usage: 7.7+ KB

# %%
df.describe()
# Out:
#        CS202_internas  IT202_internals  IT204_internals  CS208_internals  \
# count       57.000000        57.000000        57.000000        57.000000
# mean        35.192982        36.140351        39.263158        36.175439
# std          6.864605         7.935991         7.548714         6.915621
# min         23.000000        14.000000        23.000000        20.000000
# 25%         30.000000        31.000000        34.000000        30.000000
# 50%         35.000000        37.000000        41.000000        37.000000
# 75%         40.000000        43.000000        44.000000        42.000000
# max         48.000000        48.000000        50.000000        50.000000
#
#        IT232_internals  IT234_internals
# count        57.000000        57.000000
# mean         89.087719        84.754386
# std           7.590597         9.103141
# min          71.000000        63.000000
# 25%          85.000000        79.000000
# 50%          91.000000        87.000000
# ...

# %%
df['IT202_internals'].hist()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f689ffac150>,
# ...
#       dtype=object)

# %%
df['CS202'].unique()
# Out:
# array(['F', 'Absent', 'B', 'C', 'A', 'P', 'B+', 'A+', 'FE'], dtype=object)

# %%
df['CS202'].nunique()
# Out:
# 9

# %%
df['CS202'].value_counts()
# Out:
# F         18
# B         12
# C          8
# B+         7
# Absent     5
# A          3
# A+         2
# FE         1
# P          1
# Name: CS202, dtype: int64

# %%
df['CS202']
# Out:
# 0          F
# 1     Absent
# 2          B
# 3          B
# 4          C
# 5          B
# 6          F
# 7          F
# 8          F
# 9          A
# 10    Absent
# 11         P
# 12        B+
# 13        B+
# 14         F
# 15         F
# 16         B
# 17        A+
# 18         F
# 19         B
# 20        B+
# 21         F
# 22         F
# 23        A+
# 24    Absent
# 25         C
# 26    Absent
# 27         C
# 28         C
# 29         F
# 30         C
# 31         F
# 32         A
# 33         B
# 34        B+
# 35         C
# 36         F
# 37        B+
# 38         C
# 39         B
# 40         F
# 41         F
# 42         B
# 43         F
# 44        FE
# 45    Absent
# 46        B+
# 47         B
# 48         B
# 49         B
# 50        B+
# 51         A
# 52         B
# 53         F
# 54         C
# 55         F
# 56         F
# Name: CS202, dtype: object

# %%
df['CS202_internas'].mean()
# Out:
# 35.19298245614035

# %%
df['CS202_internas'].hist()

# %%
df['CS202_internas'].value_counts(normalize=True)
# Out:
# 32    0.087719
# 39    0.070175
# 35    0.052632
# 30    0.052632
# 33    0.052632
# 46    0.052632
# 36    0.052632
# 23    0.052632
# 40    0.052632
# 41    0.052632
# 44    0.035088
# 25    0.035088
# 27    0.035088
# 29    0.035088
# 31    0.035088
# 34    0.035088
# 42    0.035088
# 37    0.035088
# 48    0.035088
# 43    0.017544
# 38    0.017544
# 45    0.017544
# 28    0.017544
# 26    0.017544
# 24    0.017544
# Name: CS202_internas, dtype: float64

# %% [markdown]
# # INDEXING

# %%
df.head()
# Out:
#   Register No  CS202_internas   CS202  IT202_internals IT202  IT204_internals  \
# 0  TRV16IT001              25       F               29     F               31
# 1  TRV16IT002              35  Absent               37     B               44
# 2  TRV16IT003              48       B               47     A               45
# 3  TRV16IT005              40       B               46     A               40
# 4  TRV16IT006              34       C               43     F               42
#
#   IT204 HS200_internals HS200 MA202_internals MA202  CS208_internals CS208  \
# 0    B+              25     C              29    B+               32     C
# 1    B+              23     C              32    B+               32     C
# 2    A+              44    B+              49     O               50    A+
# 3    B+              41     A              46     O               45     A
# 4     B              40    B+              45     O               37     B
#
# ...

# %% [markdown]
# # iloc

# %%
df.iloc[0,0]  #iloc[row,column]
# Out:
# 'TRV16IT001'

# %%
df.iloc[:6,0]
# Out:
# 0    TRV16IT001
# 1    TRV16IT002
# 2    TRV16IT003
# 3    TRV16IT005
# 4    TRV16IT006
# 5    TRV16IT007
# Name: Register No, dtype: object

# %%
df.iloc[0:3,0]
# Out:
# 0    TRV16IT001
# 1    TRV16IT002
# 2    TRV16IT003
# Name: Register No, dtype: object

# %%
df.iloc[4,3]
# Out:
# 43

# %%
s=pd.DataFrame({'age':[20,21,22],'salary':[121,2344,221]},index=['adish','aneesh','asish'])

# %%
s
# Out:
#         age  salary
# adish    20     121
# aneesh   21    2344
# asish    22     221

# %% [markdown]
# # .loc

# %%
s.loc[['adish','asish'],'salary']
# Out:
# adish    121
# asish    221
# Name: salary, dtype: int64

# %%
df.head()
# Out:
#   Register No  CS202_internas   CS202  IT202_internals IT202  IT204_internals  \
# 0  TRV16IT001              25       F               29     F               31
# 1  TRV16IT002              35  Absent               37     B               44
# 2  TRV16IT003              48       B               47     A               45
# 3  TRV16IT005              40       B               46     A               40
# 4  TRV16IT006              34       C               43     F               42
#
#   IT204 HS200_internals HS200 MA202_internals MA202  CS208_internals CS208  \
# 0    B+              25     C              29    B+               32     C
# 1    B+              23     C              32    B+               32     C
# 2    A+              44    B+              49     O               50    A+
# 3    B+              41     A              46     O               45     A
# 4     B              40    B+              45     O               37     B
#
# ...

# %% [markdown]
# # BOOLEAN INDEXING

# %%
df['IT202_internals']==40
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# Name: IT202_internals, dtype: bool

# %%
(df['IT202_internals']==40).sum() #no one with mark 40
# Out:
# 0

# %%
df['IT202_internals']>40
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46     True
# 47     True
# 48    False
# 49     True
# 50     True
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# Name: IT202_internals, dtype: bool

# %%
df[df['IT202_internals']>40] #listing all those have scored marks greater than 40
# Out:
#    Register No  CS202_internas CS202  IT202_internals IT202  IT204_internals  \
# 2   TRV16IT003              48     B               47     A               45
# 3   TRV16IT005              40     B               46     A               40
# 4   TRV16IT006              34     C               43     F               42
# 5   TRV16IT007              41     B               43     B               44
# 9   TRV16IT011              46     A               45    B+               49
# 12  TRV16IT015              39    B+               45     F               50
# 13  TRV16IT016              39    B+               42     B               49
# 14  TRV16IT017              38     F               45     F               50
# 16  TRV16IT019              42     B               43     F               46
# 17  TRV16IT020              44    A+               44     B               47
# 19  TRV16IT022              40     B               41     B               42
# ...

# %%
df[(df['IT202_internals']>40) & (df['CS202_internas']>40)] #listing all those have scored marks greater than 40 for both subjects
# Out:
#    Register No  CS202_internas CS202  IT202_internals IT202  IT204_internals  \
# 2   TRV16IT003              48     B               47     A               45
# 5   TRV16IT007              41     B               43     B               44
# 9   TRV16IT011              46     A               45    B+               49
# 16  TRV16IT019              42     B               43     F               46
# 17  TRV16IT020              44    A+               44     B               47
# 23  TRV16IT026              46    A+               48     B               49
# 32  TRV16IT037              48     A               45     B               43
# 37  TRV16IT042              45    B+               42    B+               43
# 46  TRV16IT052              41    B+               44     B               48
# 49  TRV16IT055              41     B               43     F               47
# 50  TRV16IT056              44    B+               44    B+               45
# ...

# %%
df['IT202_internals']>45
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# Name: IT202_internals, dtype: bool

# %% [markdown]
# # Apply

# %%
def gooba(IT202_internals):
    return 'brilliant' if IT202_internals>45 else 'AVG'

# %%
df['IT202_internals'].apply(gooba)
# Out:
# 0           AVG
# 1           AVG
# 2     brilliant
# 3     brilliant
# 4           AVG
# 5           AVG
# 6           AVG
# 7           AVG
# 8           AVG
# 9           AVG
# 10          AVG
# 11          AVG
# 12          AVG
# 13          AVG
# 14          AVG
# 15          AVG
# 16          AVG
# 17          AVG
# 18          AVG
# 19          AVG
# 20          AVG
# 21          AVG
# 22          AVG
# 23    brilliant
# 24          AVG
# 25          AVG
# 26          AVG
# 27          AVG
# 28          AVG
# 29          AVG
# 30          AVG
# 31          AVG
# 32          AVG
# 33          AVG
# 34          AVG
# 35          AVG
# 36          AVG
# 37          AVG
# 38    brilliant
# 39          AVG
# 40          AVG
# 41          AVG
# 42          AVG
# 43          AVG
# 44          AVG
# 45          AVG
# 46          AVG
# 47          AVG
# 48          AVG
# 49          AVG
# 50          AVG
# 51          AVG
# 52          AVG
# 53          AVG
# 54          AVG
# ...

# %% [markdown]
# # Apply and lambda

# %%
df['IT202_internals'].apply(lambda IT202_internals:'brilliant' if IT202_internals>45 else 'AVG')
# Out:
# 0           AVG
# 1           AVG
# 2     brilliant
# 3     brilliant
# 4           AVG
# 5           AVG
# 6           AVG
# 7           AVG
# 8           AVG
# 9           AVG
# 10          AVG
# 11          AVG
# 12          AVG
# 13          AVG
# 14          AVG
# 15          AVG
# 16          AVG
# 17          AVG
# 18          AVG
# 19          AVG
# 20          AVG
# 21          AVG
# 22          AVG
# 23    brilliant
# 24          AVG
# 25          AVG
# 26          AVG
# 27          AVG
# 28          AVG
# 29          AVG
# 30          AVG
# 31          AVG
# 32          AVG
# 33          AVG
# 34          AVG
# 35          AVG
# 36          AVG
# 37          AVG
# 38    brilliant
# 39          AVG
# 40          AVG
# 41          AVG
# 42          AVG
# 43          AVG
# 44          AVG
# 45          AVG
# 46          AVG
# 47          AVG
# 48          AVG
# 49          AVG
# 50          AVG
# 51          AVG
# 52          AVG
# 53          AVG
# 54          AVG
# ...

# %%
df['IT202_internals'].map({48:'BRILLIANT',14:'BELOW AVG'})
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23    BRILLIANT
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44    BELOW AVG
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# ...

# %%
x=input('enter your gender: ')
print('hai {} '.format('men' if x=='male' else ('women' if x=='female' else ( 'reppaaaa' if x=='gey' else 'other gender'))))
# Out:
# enter your gender: male
# hai men
