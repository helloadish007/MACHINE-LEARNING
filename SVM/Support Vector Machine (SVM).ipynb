# %% [markdown]
# ## A Support Vector Machine (SVM) is a discriminative classifier formally defined by a separating hyperplane. In other words, given labeled training data (supervised learning), the algorithm outputs an optimal hyperplane which categorizes new examples. In two dimentional space this hyperplane is a line dividing a plane in two parts where in each class lay in either side.

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm1.jpeg')

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm2.jpeg')

# %% [markdown]
# ### many possible ways to draw the boundaries separating those 2 classes. What is the best line which separates both of them?

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm3.jpeg')

# %% [markdown]
# ### take the line with higher margin

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm4.jpeg')

# %% [markdown]
# ### 2D-- Boundary will be a line
# ### 3D-- Boundary will be a plane

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm5.jpeg')

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm6.jpeg')

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm7.jpeg')

# %% [markdown]
# ### Bias is know as the difference between the average prediction of our model and the actual(correct) value. If the average predicted values are far off from the actual values then the bias is high.

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm10.png')

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm11.png')

# %% [markdown]
# The first one tolerates some outlier points. The second one is trying to achieve 0 tolerance with perfect partition.
#
# But, there is trade off. In real world application, finding perfect class for millions of training data set takes lot of time. As you will see in coding. This is called regularization parameter.

# %% [markdown]
# ### Regularization  Parameter
#
# The Regularization parameter (often termed as C parameter in python’s sklearn library) tells the SVM optimization how much you want to avoid misclassifying each training example.
#
# For large values of C, the optimization will choose a smaller-margin hyperplane if that hyperplane does a better job of getting all the training points classified correctly. Conversely, a very small value of C will cause the optimizer to look for a larger-margin separating hyperplane, even if that hyperplane misclassifies more points.

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm8.jpeg')

# %% [markdown]
# ### Gamma
#
# with low gamma, points far away from plausible seperation line are considered in calculation for the seperation line. Where as high gamma means the points close to plausible line are considered in calculation.

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm12.png')

# %%
from IPython.display import Image
Image('/home/adish/Downloads/svm13.png')

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
#printing rows with target=1
df[df.target==1]  #versicolor starts from 50  to 99
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# ...

# %%
#printing rows with target=2
df[df.target==2]  #virginica starts from 100 to 149
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %%
#from 1 column you want to generate another column , for that you can use apply() function.
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
iris.target_names
#here index of setosa=0 versicolor=1 and virginica=2
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
 from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df0=df[df.target==0]
df1=df[df.target==1]
df2=df[df.target==2]
df0.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df1.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower_name
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %%
df2.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower_name
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %% [markdown]
# ### Plot of petal length vs petal width of setosa vs versicolor

# %%
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'],color="red",marker='+')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'],color="green",marker='.')

# %% [markdown]
# ### Plot of sepal length vs sepal width of setosa vs versicolor

# %%
plt.xlabel('sepal Length')
plt.ylabel('sepal Width')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'],color="red",marker='+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'],color="green",marker='.')

# %%
x=df.iloc[:,:-2]
y=df.target

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(xtest,ytest)
# Out:
# 0.9

# %% [markdown]
# ### NOTE: use linear SVMs (or logistic regression) for linear problems, and nonlinear kernels such as the Radial Basis Function kernel for non-linear problems.

# %% [markdown]
# # Tuning model by giving different parameter values
#
# ### Regularization

# %%
model_r = SVC(C=1)
model_r.fit(xtrain, ytrain)
model_r.score(xtest, ytest)
# Out:
# 0.9

# %%
model_r = SVC(C=10)
model_r.fit(xtrain, ytrain)
model_r.score(xtest, ytest)
# Out:
# 0.9333333333333333

# %%
model_r = SVC(C=20)
model_r.fit(xtrain, ytrain)
model_r.score(xtest, ytest)
# Out:
# 0.9333333333333333

# %% [markdown]
# ### gamma

# %%
model_g = SVC(gamma=10)
model_g.fit(xtrain, ytrain)
model_g.score(xtest, ytest)
# Out:
# 0.8333333333333334

# %%
model_g = SVC(gamma=100)
model_g.fit(xtrain, ytrain)
model_g.score(xtest, ytest)
# Out:
# 0.5

# %% [markdown]
# ### kernel

# %%
model_linear_kernal = SVC(kernel='linear')
model_linear_kernal.fit(xtrain, ytrain)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model_linear_kernal.score(xtest, ytest)
# Out:
# 0.9333333333333333
